# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\gonca\Desktop\mestrado\ML\test.csv")
train = pd.read_csv(r"C:\Users\gonca\Desktop\mestrado\ML\train.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32567 entries, 0 to 32566
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   carID           32567 non-null  int64
#  1   Brand           31918 non-null  object
#  2   model           31917 non-null  object
#  3   year            31914 non-null  float64
#  4   transmission    31944 non-null  object
#  5   mileage         31878 non-null  float64
#  6   fuelType        31911 non-null  object
#  7   tax             29259 non-null  float64
#  8   mpg             29279 non-null  float64
#  9   engineSize      31939 non-null  float64
#  10  paintQuality%   31942 non-null  float64
#  11  previousOwners  31970 non-null  float64
#  12  hasDamage       31970 non-null  float64
# dtypes: float64(8), int64(1), object(4)
# memory usage: 3.2+ MB

# %%
df.isna().sum()
# Out:
# carID                0
# Brand              649
# model              650
# year               653
# transmission       623
# mileage            689
# fuelType           656
# tax               3308
# mpg               3288
# engineSize         628
# paintQuality%      625
# previousOwners     597
# hasDamage          597
# dtype: int64

# %% [markdown]
# ## Data Preparation

# %%
#ver fuzzy matching

# %% [markdown]
# ### carID

# %%
df_concat = pd.concat([df, train], ignore_index=True)

duplicates = df_concat.duplicated().any()
print(duplicates)

df_concat[df_concat.duplicated(['carID'])]
# Out:
# False
# Empty DataFrame
# Columns: [carID, Brand, model, year, transmission, mileage, fuelType, tax, mpg, engineSize, paintQuality%, previousOwners, hasDamage, price]
# Index: []

# %% [markdown]
# <b>An attribute that contains an identifier for each car.
# * The carID variable is 100% distinct across all records, hence we can use it as an index.

# %%
df = df.set_index(["carID"])
train = train.set_index(["carID"])

# %% [markdown]
# ### Brand

# %%
print(df["Brand"].unique())
# Out:
# ['Hyundai' 'VW' 'BMW' 'Opel' 'Ford' 'Mercedes' 'Skoda' 'Toyot' 'Toyota'
#  'Audi' nan 'For' 'Ope' 'toyota' 'vw' 'hyundai' 'MW' 'SKODA' 'ord' 'udi'
#  'bmw' 'V' 'BM' 'HYUNDAI' 'OPEL' 'mercedes' 'audi' 'Mercede' 'pel' 'opel'
#  'FORD' 'yundai' 'ford' 'Aud' 'oyota' 'MERCEDES' 'ercedes' 'AUDI' 'koda'
#  'Hyunda' 'W' 'skoda' 'Skod' 'ercede' 'TOYOTA' 'ERCEDES' 'kod' 'ORD' 'v'
#  'ud' 'M' 'FOR' 'for' 'MERCEDE' 'YUNDAI' 'PEL' 'ope' 'or' 'TOYOT' 'hyunda'
#  'oyot' 'UDI' 'mw' 'pe' 'bm']

# %%
df["Brand"] = df["Brand"].str.lower()
df["Brand"] = df["Brand"].str.strip()

# %%
brand_map = {
    "bmw": "BMW", "bm": "BMW", "mw": "BMW",
    "mercedes": "Mercedes", "mercede": "Mercedes", "mercede": "Mercedes", "ercedes": "Mercedes", "ercede": "Mercedes",
    "toyota": "Toyota", "toyo": "Toyota", "toyot": "Toyota", "oyota": "Toyota" ,"oyot": "Toyota" ,
    "hyundai": "Hyundai", "hyunda": "Hyundai", "yundai": "Hyundai",
    "skoda": "Skoda", "skod": "Skoda", "kod": "Skoda", "koda": "Skoda",
    "opel": "Opel", "ope": "Opel", "pel": "Opel", "pe": "Opel",
    "ford": "Ford", "for": "Ford", "ord": "Ford",
    "audi": "Audi", "udi": "Audi", "aud": "Audi", 
    "vw": "Volkswagen"
}

df["Brand"] = df["Brand"].map(lambda x: brand_map.get(x, x))

# %%
print(df["Brand"].unique())
#da para inferir algumas marcas com base nos modelos
# Out:
# ['Hyundai' 'Volkswagen' 'BMW' 'Opel' 'Ford' 'Mercedes' 'Skoda' 'Toyota'
#  'Audi' nan 'v' 'w' 'ud' 'm' 'or']

# %% [markdown]
# ### Model

# %%
print(df["model"].value_counts())
# Out:
# model
#  Focus        2721
#  C Class      2037
#  Fiesta       1813
#  Golf         1317
#  Corsa         942
#               ...
# YARIS            1
#  I3              1
# yaris            1
# Combo Life       1
#  GOLF SV         1
# Name: count, Length: 593, dtype: int64

# %%
df["model"] = df["model"].str.lower()
df["model"] = df["model"].str.strip()

# %%
df["model"].unique()
# Out:
# array(['i30', 'tiguan', '2 series', 'grandland x', '1 series', 'fiesta',
#        'x1', 'b class', 'focus', 'superb', '5 series', 'c class', 'up',
#        'aygo', 'golf', 'm clas', 'land cruiser', 'tt', 'adam', 'zafira',
#        'e class', '3 series', 'ix20', 'a4', 'yaris', 'passat', 'i10',
#        'mokka x', 'ecosport', '4 series', 'a7', 'corsa', 'kuga',
#        'grand c-max', 'q2', 'm4', 'a class', 'rav4', 'fabia', 'insignia',
#        'a1', 'x6', 'meriva', 'caravelle', 'octavia', 'auris', 'x-class',
#        'astra', 'v class', 'polo', 'karoq', 'shuttle', 'mokka', 'q5',
#        'tucson', 'a3', 'sl class', 'corolla', 'ka+', 'x3', 'i40', 'i20',
#        'kamiq', nan, 'ix35', 'crossland x', 'q3', 'viva', 'gla class',
#        'astr', 'cls class', 'ka', 'focu', 'galaxy', 'x2', 'kodiaq',
#        'glc class', 'vivaro', 'mondeo', 'touran', 'cl class', 'x5',
#        'verso', 'touareg', 't-roc', 'fiest', 'q', 'a5', 's class',
#        'c clas', 'scirocco', 'x7', 'b-max', '8 series', 'a6', 'santa fe',
#        'gl class', 'gle class', 'beetle', 'x4', 'pol', 'golf sv',
#        'octavi', 'sharan', 'gol', 'c-max', 'm6', 'a8', 'cla class',
#        'kona', 'citigo', 'prius', 'rapid', 'fusion', '3 serie', 'g clas',
#        'slk', 'yeti outdoor', 'q7', 'c-hr', 'm5', 't-cross', 'avensis',
#        'ioniq', 'amarok', 'viv', 'z4', 'california', 'm2', 'm3', 'arteon',
#        '1 serie', 'scala', 'hilux', 'puma', 'gtc', 'fabi',
#        'zafira tourer', 's-max', 'super', 'edge', 'cc', 'rs3', 'x',
#        'auri', 'tiguan allspace', 'rs4', 'combo life', 'caddy maxi life',
#        'tourneo custom', 'mustang', 'yari', '7 series', 'yeti', '2 serie',
#        'zafir', 'arteo', 'veloster', 'mokk', 'u', 'a', 'i800', 'rav',
#        'tiguan allspac', 'b-ma', 'monde', 'm class', '4 serie', 's-ma',
#        'grandland', 'fox', 'glb class', 'kug', '6 series', 'iq', 'r8',
#        'tucso', 'gt86', 'cors', 'agila', 'gls class', 'rs5', 'ecospor',
#        'cl clas', 'e clas', 'grand tourneo connect', 't-ro', 'antara',
#        'x-clas', 'i2', '180', 'supra', 'sq5', 'ayg', 'yeti outdoo',
#        'glc clas', 'citig', 'q8', 'tourneo custo', 'sq7', 'toura', 'i8',
#        'tourneo connect', 'coroll', 'i3', 'hilu', 'g class', '6 serie',
#        'kon', 'a clas', 'caddy life', 'jetta', 'passa', 'r class',
#        'b clas', 'edg', 'insigni', 's3', '5 serie', 'gla clas',
#        'caravell', 'amica', 'crossland', 't', 'rs6', 'tigua',
#        'proace verso', 'camry', 'sl clas', 'tigra', 'c-h', 'eos', 'm',
#        'combo lif', 'roomster', 'santa f', 'clk', 'californi', 'meriv',
#        'ampera', 'i1', 'kodia', 'c-ma', 's5', 'clc class', 'galax', 'ada',
#        'shara', 'grand tourneo connec', 'rs7', 'scirocc',
#        'transit tourneo', 's clas', 'vectra', 'golf s', 'caddy', 'i4',
#        'cla clas', 'grand c-ma', 'gl clas', 'pum', 'z3', 'sl', 'gls clas',
#        's4', 'terracan', 'rapi', 'k', 'camr', 'cascada'], dtype=object)

# %% [markdown]
# ### year

# %%
df["year"].unique()
# Out:
# array([2022.87800554, 2017.        , 2016.        , 2019.        ,
#        2018.        , 2011.        , 2015.        ,           nan,
#        2023.26798867, 2014.        , 2020.        , 2013.        ,
#        2010.        , 2024.12175905, 2008.        , 2012.        ,
#        2010.56500919, 2010.37154646, 2011.21085349, 2009.        ,
#        2022.69668507, 2007.        , 2023.38982198, 2023.97731126,
#        2023.36707842, 2004.        , 2010.26863473, 2010.67696784,
#        2023.1169636 , 2002.        , 2023.60527574, 2012.69574039,
#        2006.        , 2000.        , 2003.        , 1997.        ,
#        2011.11118842, 2009.81675711, 2010.7464032 , 2001.        ,
#        1999.        , 1998.        , 2005.        , 1991.        ,
#        1996.        ])

# %%
#por agora nulos ficom com 9999
df["year"] = df["year"].fillna(9999)

# Ficar só com a parte inteira e converter para int
df["year"] = df["year"].astype(float).astype(int)

print(df["year"].unique())
print(df.dtypes)
# Out:
# [2022 2017 2016 2019 2018 2011 2015 9999 2023 2014 2020 2013 2010 2024
#  2008 2012 2009 2007 2004 2002 2006 2000 2003 1997 2001 1999 1998 2005
#  1991 1996]
# Brand              object
# model              object
# year                int64
# transmission       object
# mileage           float64
# fuelType           object
# tax               float64
# mpg               float64
# engineSize        float64
# paintQuality%     float64
# previousOwners    float64
# hasDamage         float64
# dtype: object

# %% [markdown]
# ### transmission

# %%
df["transmission"].unique()
# Out:
# array(['Automatic', 'Semi-Auto', 'Manual', 'unknow', 'Manua', 'automatic',
#        nan, 'semi-auto', 'MANUAL', 'Semi-Aut', 'unknown', 'emi-Auto',
#        'utomatic', 'SEMI-AUTO', 'anual', 'Automati', 'manual',
#        'AUTOMATIC', ' Manual ', ' Manual', 'UNKNOWN', 'anua', 'AUTOMATI',
#        'nknown', 'MANUA', 'Other', ' MANUAL ', 'manual ', 'manua',
#        'UTOMATIC', 'automati', 'utomati', 'ANUAL', 'emi-auto', 'EMI-AUTO',
#        'SEMI-AUT', 'Manual ', ' manual ', 'emi-Aut'], dtype=object)

# %%
df["transmission"] = df["transmission"].str.lower().str.strip()
df["transmission"].unique()
# Out:
# array(['automatic', 'semi-auto', 'manual', 'unknow', 'manua', nan,
#        'semi-aut', 'unknown', 'emi-auto', 'utomatic', 'anual', 'automati',
#        'anua', 'nknown', 'other', 'utomati', 'emi-aut'], dtype=object)

# %%
df["transmission"] = df["transmission"].str.lower().str.strip()

# Criar mapeamento só para marcas que já vi no teu print
trans_map = {
    "automatic": "Automatic", "utomatic": "Automatic", "automati": "Automatic","utomati": "Automatic",
    "semi-auto": "Semi-Auto", "semi-aut": "Semi-Auto","emi-auto": "Semi-Auto", "emi-aut": "Semi-Auto",
    "manual": "Manual", "manua": "Manual","anual": "Manual", "anua": "Manual",
    "unknow": "Unknown", "unknown": "Unknown", "nknown": "Unknown",
    "other": "Other"
}

# Substituir se existir no dicionário
df["transmission"] = df["transmission"].map(lambda x: trans_map.get(x, x))

# Ver marcas únicas já limpas
print(df["transmission"].unique())
# Out:
# ['Automatic' 'Semi-Auto' 'Manual' 'Unknown' nan 'Other']

# %% [markdown]
# ### mileage

# %%
df["mileage"].unique()
#tem de ser numero e tem de ser poitivo
# Out:
# array([ 30700.        , -48190.65567291,  36792.        , ...,
#         27575.        ,   8297.        ,  11071.        ])

# %%
#Verificar os pontos que existem nos dados

# %%
print("Mínimo:", df['mileage'].min())
print("Máximo:", df['mileage'].max())
print("Média:", df['mileage'].mean())
print("Mediana:", df['mileage'].median())
print("Desvio padrão:", df['mileage'].std())
# Out:
# Mínimo: -58540.5744775577
# Máximo: 279000.0
# Média: 22952.658921255734
# Mediana: 17225.5
# Desvio padrão: 22132.75871325435

# %%
#Verificar dados abixo 0, visto não pretendermos ter quilometros negativos

# %%
df[df["mileage"]<0]
# Out:
#            Brand     model    year transmission       mileage fuelType    tax  \
# carID
# 106581        VW    Tiguan  2017.0    Semi-Auto -48190.655673   Petrol  150.0
# 92673   Mercedes   C Class  2017.0      unknown -50755.210230   Diesel    NaN
# 93065   Mercedes   C Class  2019.0    Semi-Auto -50755.210230   Petrol    NaN
# 89444    Hyundai    Tucson  2020.0    Semi-Auto -36635.042697   Hybrid  150.0
# 85269       Ford    Mondeo  2017.0    Automatic -42650.453719   Diesel   20.0
# ...          ...       ...     ...          ...           ...      ...    ...
# 100676       Ope   Cascada  2015.0       Manual -42707.564215   Diesel  125.0
# 92455   Mercedes   C Class  2019.0    Semi-Auto -50755.210230    Petro    NaN
# 106053        VW      Polo  2017.0       Manual -48190.655673    etrol   20.0
# 95430   Mercedes   A Class  2016.0       Manual -50755.210230   Petrol  125.0
# 91768   Mercedes   A Class  2019.0       Manual -50755.210230   Petrol  145.0
#
#          mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 106581  38.2         2.0           60.0             2.0        0.0
# 92673    NaN         2.1           93.0             2.0        0.0
# 93065    NaN         3.0           97.0             4.0        0.0
# 89444   50.4         1.6           41.0             0.0        0.0
# 85269   67.3         2.0           31.0             0.0        0.0
# ...      ...         ...            ...             ...        ...
# 100676  57.6         2.0           77.0             2.0        0.0
# 92455    NaN         2.0           59.0             2.0        0.0
# 106053  58.9         1.0           72.0             4.0        0.0
# 95430   51.4         1.6           58.0             1.0        0.0
# 91768   28.5         1.3           81.0             1.0        0.0
#
# [170 rows x 12 columns]

# %%
#poderiamos trocar todos os dados para valores positivos, mas mais correto era passar todos os negativos para NaN e efetuar a mediana de todos os valores e subsituir por os mesmos

# %%
df.loc[df["mileage"] < 0, "mileage"] = np.nan

# %%
median_mileage = df["mileage"].median()

# %%
df["mileage"] = df["mileage"].fillna(median_mileage)

# %%
#efeutamos todas as alterações, verificar os dados corrigidos

# %%
df[df["mileage"]<0]
# Out:
# Empty DataFrame
# Columns: [Brand, model, year, transmission, mileage, fuelType, tax, mpg, engineSize, paintQuality%, previousOwners, hasDamage]
# Index: []

# %%
print("Mínimo:", df['mileage'].min())
print("Máximo:", df['mileage'].max())
print("Número de NaN:", df['mileage'].isna().sum())
# Out:
# Mínimo: 1.0
# Máximo: 279000.0
# Número de NaN: 0

# %% [markdown]
# ### fuelType

# %%
df["fuelType"].unique()
# Out:
# array(['petrol', 'Petrol', 'Diesel', 'Diese', 'Hybrid', 'iesel', 'Petro',
#        'hybrid', 'etrol', 'DIESEL', nan, 'PETROL', 'diesel', 'Other',
#        'iese', 'diese', 'etro', 'petro', 'HYBRID', 'Hybri', 'ther',
#        'ETROL', 'ybrid', 'IESEL', 'DIESE', 'PETRO', 'hybri', 'other',
#        'Othe', 'Electric'], dtype=object)

# %%
# Normalizar (minúsculas + remover espaços)
df["fuelType"] = df["fuelType"].str.lower().str.strip()

# Mapeamento só com o que foi encontrado
fuel_map = {
    # Petrol
    "petrol": "Petrol", "petro": "Petrol", "etro": "Petrol","etrol": "Petrol",
    
    # Diesel
    "diesel": "Diesel", "diese": "Diesel", "iesel": "Diesel","iese": "Diesel",
    
    # Hybrid
    "hybrid": "Hybrid", "hybri": "Hybrid","ybrid": "Hybrid",
    
    # Electric
    "electric": "Electric",
    
    # Other
    "other": "Other", "othe": "Other", "ther": "Other"
}

# Aplicar mapeamento
df["fuelType"] = df["fuelType"].map(lambda x: fuel_map.get(x, x))

# Substituir NaN por "Unknown"
df["fuelType"] = df["fuelType"].fillna("Unknown")

# Ver categorias finais
print(df["fuelType"].unique())
# Out:
# ['Petrol' 'Diesel' 'Hybrid' 'Unknown' 'Other' 'Electric']

# %% [markdown]
# ### tax

# %% [markdown]
# ### mpg

# %%
df["mpg"].unique() #os MPG não pode ter valores Nan nem valores negativos e absurdos
# Out:
# array([ 4.15000000e+01,  3.82000000e+01,  5.14000000e+01,  4.41000000e+01,
#         6.57000000e+01,  5.89000000e+01,  4.79000000e+01,  6.42000000e+01,
#         6.28000000e+01,  6.14000000e+01,  9.47863804e+01,  6.90000000e+01,
#         3.98000000e+01,  3.04000000e+01,  3.92000000e+01,  3.01000000e+01,
#         5.77000000e+01,  5.33000000e+01,             nan,  4.09000000e+01,
#         6.73000000e+01,  5.04000000e+01,  6.89000000e+01,  7.63000000e+01,
#         4.96000000e+01,  4.22000000e+01,  1.00998943e+02,  8.60000000e+01,
#         7.85000000e+01,  4.87000000e+01,  3.77000000e+01,  5.43000000e+01,
#         6.01000000e+01,  1.66000000e+02,  3.25000000e+01,  4.35000000e+01,
#         5.23000000e+01,  4.56000000e+01,  5.76000000e+01,  3.49000000e+01,
#         4.71000000e+01,  2.94000000e+01,  7.24000000e+01,  3.58000000e+01,
#         7.43000000e+01,  3.67000000e+01,  4.28000000e+01,  3.28000000e+01,
#         4.04000000e+01,  3.62000000e+01,  6.17000000e+01,  3.44000000e+01,
#         5.54000000e+01,  3.72000000e+01,  2.88000000e+01,  2.07454998e+01,
#         5.65000000e+01,  4.30000000e+01,  8.15689396e+01,  3.17000000e+01,
#         3.21000000e+01,  6.70000000e+01,  5.50000000e+01,  4.63000000e+01,
#         1.10344977e+02,  4.48000000e+01,  7.06000000e+01,  3.14000000e+01,
#         2.46000000e+01,  3.36000000e+01,  6.60000000e+01,  9.42917895e+00,
#         2.80000000e+01,  5.80000000e+01,  1.88300000e+02,  1.34500000e+02,
#         3.40000000e+01,  2.69000000e+01,  8.31000000e+01,  8.83000000e+01,
#         2.48000000e+01,  7.64000000e+01,  2.85000000e+01,  2.50000000e+01,
#         8.56000000e+01,  5.88000000e+01,  5.11000000e+01,  3.53000000e+01,
#         3.10000000e+01,  2.14000000e+01,  3.32000000e+01,  3.87000000e+01,
#         1.66200000e+02,  3.45000000e+01,  1.51041810e+02,  2.77094895e+01,
#         4.77000000e+01,  2.91000000e+01,  8.83216395e+01,  9.28268995e+01,
#         2.07100948e+01,  8.07000000e+01,  7.80000000e+01,  3.07000000e+01,
#         2.72000000e+01,  2.64000000e+01,  5.66000000e+01,  1.63501525e+01,
#         4.36000000e+01,  6.88000000e+01,  1.14172678e+01,  2.74000000e+01,
#         9.41000000e+01,  1.41200000e+02,  7.84000000e+01,  9.21104552e+01,
#         1.56900000e+02,  1.44971463e+01,  4.21000000e+01,  2.21000000e+01,
#         6.11000000e+01,  2.67000000e+01,  6.56000000e+01,  2.82000000e+01,
#         2.77000000e+01,  4.03000000e+01,  4.34000000e+01,  1.00900000e+02,
#         2.59000000e+01,  2.30000000e+01,  8.97736927e+01,  7.86000000e+01,
#         9.82146197e+00,  5.13000000e+01,  1.48700000e+02,  2.97000000e+01,
#        -4.34217675e+01,  2.26000000e+01,  2.80000000e+00,  2.41000000e+01,
#         2.39000000e+01,  1.41300000e+02,  4.60000000e+01,  8.80000000e+00,
#         2.37000000e+01,  5.44000000e+01,  4.70800000e+02,  2.10000000e+01,
#         2.56800000e+02,  2.95000000e+01,  3.00000000e+01,  2.17300000e+02,
#         2.33000000e+01,  4.45000000e+01,  5.55000000e+01,  4.70000000e+01,
#         3.76000000e+01,  1.17700000e+02,  2.16000000e+01,  3.86000000e+01,
#         2.28000000e+01,  2.09000000e+01,  6.27000000e+01,  5.50000000e+00,
#         4.80000000e+01,  2.35000000e+02,  1.89000000e+01,  5.30000000e+01,
#         1.76600000e+02,  2.35400000e+02,  2.11000000e+01,  2.55000000e+01,
#         2.54000000e+01,  7.44000000e+01,  5.00000000e+01,  2.19000000e+01,
#         3.29000000e+01,  2.01800000e+02,  1.13000000e+02,  2.24000000e+01,
#         3.71000000e+01,  2.32000000e+01,  3.00000000e-01,  1.22800000e+02,
#         2.35000000e+01,  2.08000000e+01,  1.10000000e+01,  2.66000000e+01,
#         2.63000000e+01])

# %%
print("Mínimo:", df["mpg"].min())
print("Máximo:", df["mpg"].max())
print("Média:", df["mpg"].mean())
print("Desvio padrão:", df["mpg"].std())
# Out:
# Mínimo: -43.42176751067029
# Máximo: 470.8
# Média: 55.21072849324994
# Desvio padrão: 17.644634577164133

# %%
# verificamos valores negativos de mpg que não pode ser e valores de 470 mpg que é muito alto

# %%
#trocar todos os negativos para nan etodos os valores acima de 100 também - por serem valores extremamente altos para rpm

# %%
num_missing = df["mpg"].isna().sum()
print(f"Número de valores ausentes: {num_missing}")
# Out:
# Número de valores ausentes: 3288

# %%
df.loc[df["mpg"] < 0, "mpg"] = np.nan
df.loc[df["mpg"] > 100, "mpg"] = np.nan

# %%
num_missing = df["mpg"].isna().sum()
print(f"Número de valores ausentes: {num_missing}")
# Out:
# Número de valores ausentes: 3534

# %%
#trocar os mesmos pela mediana, uma vez que temos valores muito distantes dos padroes como o 470 (valor máximo)

# %%
df.fillna({"mpg": median_mpg}, inplace=True)

# %%
print("Mínimo:", df["mpg"].min())
print("Máximo:", df["mpg"].max())
print("Média:", df["mpg"].mean())
print("Desvio padrão:", df["mpg"].std())
# Out:
# Mínimo: 0.3
# Máximo: 94.786380415261
# Média: 54.3609852536347
# Desvio padrão: 11.175242042338713

# %% [markdown]
# ### engineSize

# %%
df["engineSize"].unique()
# Out:
# array([ 1.6       ,  2.        ,  1.5       ,  1.2       ,  1.        ,
#                nan,  2.1       ,  3.        ,  2.8       ,  1.4       ,
#         2.5       ,  1.8       ,  2.3       ,  1.7       ,  2.98579344,
#         1.1       ,  4.        ,  2.9       ,  2.6631132 ,  1.3       ,
#         3.2       ,  2.06411863,  2.2       ,  5.5       ,  3.82275785,
#         0.        , -0.1034928 ,  0.19146242,  3.72371217,  0.31340658,
#         6.3       ,  0.18642488,  4.4       ,  3.5       ,  2.4       ,
#         3.73923548,  0.16286595,  4.2       ,  0.30707394,  5.        ,
#         2.63120047,  5.2       ,  6.2       ,  0.7395339 ,  2.61964142,
#         2.78177621,  0.15452932,  2.7       ,  1.9       ,  0.37112737,
#         3.7       ,  4.7       ,  0.6       ,  5.4       ,  6.        ,
#         4.1       ,  6.6       ])

# %%
# a verificar os valores acima não pode haver valores nan, 0 e negativos para tamanhos do motor

# %%
invalid_values = df[(df["engineSize"].isna()) | (df["engineSize"] <= 0)]
print(invalid_values)
# Out:
#            Brand           model         year transmission  mileage fuelType  \
# carID
# 95250   Mercedes         B Class  2017.000000       Manual  14005.0   Diesel
# 91709   Mercedes          M CLAS  2015.000000    Automatic  68279.0   Diesel
# 90923   Mercedes         C Class  2019.000000    Automatic   6328.0   Petrol
# 77254       Audi               Q  2010.371546    Semi-Auto  17085.0   Petrol
# 103046      Opel        Insignia  2017.000000       Manual  26446.0   Diesel
# ...          ...             ...          ...          ...      ...      ...
# 107249        VW              Up  2017.000000       Manual  34604.0   Petrol
# 93841   Mercedes         E Class  2019.000000    Semi-Auto  12542.0   Petrol
# 101524      Opel          Zafira  2016.000000       Manual  20619.0   Petrol
# 103453      OPEL   Zafira Tourer          NaN       Manual  12886.0   Petrol
# 99306     Toyota            Aygo  2017.000000       Manual   8434.0   Petrol
#
#           tax   mpg  engineSize  paintQuality%  previousOwners  hasDamage
# carID
# 95250   145.0  65.7         NaN           64.0        4.000000        0.0
# 91709   300.0  39.2         NaN           53.0        3.000000        0.0
# 90923     NaN  54.3         NaN           70.0        2.000000        0.0
# 77254   150.0  47.9         NaN           63.0        3.000000        0.0
# 103046  150.0  54.3         NaN           63.0        1.000000        0.0
# ...       ...   ...         ...            ...             ...        ...
# 107249  145.0  64.2         NaN           32.0        2.000000        0.0
# 93841   145.0  40.4         NaN           39.0        3.000000        0.0
# 101524  200.0  42.2         NaN           96.0        3.000000        0.0
# 103453  200.0  42.2         NaN           94.0       -2.299439        0.0
# 99306   145.0  54.3         NaN           34.0        2.000000        0.0
#
# [754 rows x 12 columns]

# %%
df = df[df["engineSize"] > 0] #remover todos os valores NaN, 0 e negativos

# %%
print(df["engineSize"].unique())
# Out:
# [1.6        2.         1.5        1.2        1.         2.1
#  3.         2.8        1.4        2.5        1.8        2.3
#  1.7        2.98579344 1.1        4.         2.9        2.6631132
#  1.3        3.2        2.06411863 2.2        5.5        3.82275785
#  0.19146242 3.72371217 0.31340658 6.3        0.18642488 4.4
#  3.5        2.4        3.73923548 0.16286595 4.2        0.30707394
#  5.         2.63120047 5.2        6.2        0.7395339  2.61964142
#  2.78177621 0.15452932 2.7        1.9        0.37112737 3.7
#  4.7        0.6        5.4        6.         4.1        6.6       ]

# %%
#os valores postivos arredondar a uma casa decimal

# %%
df["engineSize"] = df["engineSize"].round(1)

# %%
print(df["engineSize"].unique())
# Out:
# [1.6 2.  1.5 1.2 1.  2.1 3.  2.8 1.4 2.5 1.8 2.3 1.7 1.1 4.  2.9 2.7 1.3
#  3.2 2.2 5.5 3.8 0.2 3.7 0.3 6.3 4.4 3.5 2.4 4.2 5.  2.6 5.2 6.2 0.7 1.9
#  0.4 4.7 0.6 5.4 6.  4.1 6.6]

# %%
print("Mínimo:", df["engineSize"].min())
print("Máximo:", df["engineSize"].max())
# Out:
# Mínimo: 0.2
# Máximo: 6.6

# %%
### Removemos abaixo de 1 ?

# %% [markdown]
# ### paintQuality%

# %%
df["paintQuality%"].unique()
#decidir o que fazer com os superior a 100. 1) truncar para 100. 2) apagar e preencher com a mediana 3)apagar e knn
# Out:
# array([ 61.        ,  60.        ,  94.        ,  77.        ,
#         45.        ,  64.        ,  50.        ,  71.        ,
#         99.        ,  73.        ,  78.        ,  40.        ,
#         35.        ,  76.        ,  53.        ,  90.        ,
#                 nan,  42.        ,  70.        ,  75.        ,
#         79.        ,  98.        ,  62.        ,  88.        ,
#         59.        ,  97.        ,  85.        ,  89.        ,
#         92.        ,  63.        ,  36.        ,  56.        ,
#         54.        ,  52.        ,  66.        ,  80.        ,
#         91.        ,  31.        ,  37.        ,  67.        ,
#         30.        ,  84.        ,  69.        ,  55.        ,
#         57.        ,  48.        ,  44.        ,  39.        ,
#         82.        ,  34.        ,  33.        , 125.10995148,
#          3.20741784,  65.        ,  86.        ,  74.        ,
#        125.00377307,  87.        ,  72.        ,  93.        ,
#         46.        ,  38.        ,  47.        ,  49.        ,
#         83.        ,  96.        ,  51.        ,  32.        ,
#         81.        ,  43.        ,  95.        ,  41.        ,
#         68.        ,  58.        ,   3.17268306,   1.76947364,
#          3.22574362, 125.30194543, 125.5694986 ,   3.1152953 ,
#          3.25476013,   3.14037046, 125.59430832, 125.36650692,
#          2.72515272, 125.18872876,   1.63891309, 125.20203342,
#        125.4535988 ])

# %% [markdown]
# ### previousOwners

# %%
df["previousOwners"].unique()
# Out:
# array([ 3.        ,  2.        ,  1.        ,  4.        ,  0.        ,
#                nan, -2.34565   ,  6.25823052,  6.23017958,  6.25837066,
#        -2.29943868,  6.21772443, -2.33512284,  6.2482512 ,  6.23308217,
#        -2.33744529,  6.24583495,  6.24177863, -2.33936045, -2.31225953,
#        -2.34030622, -2.31733109, -2.34010209,  6.22789796])

# %%
# Substituir NaN por 9999 (ou outro valor que prefiras, ex: 0)
df["previousOwners"] = df["previousOwners"].fillna(9999)

# Converter para inteiro
df["previousOwners"] = df["previousOwners"].astype(float).astype(int)

# Tornar valores negativos em positivos
df["previousOwners"] = df["previousOwners"].abs()

print(df["previousOwners"].unique())
print(df.dtypes)
# Out:
# [   3    2    1    4    0 9999    6]
# Brand              object
# model              object
# year                int64
# transmission       object
# mileage           float64
# fuelType           object
# tax               float64
# mpg               float64
# engineSize        float64
# paintQuality%     float64
# previousOwners      int64
# hasDamage         float64
# dtype: object

# %% [markdown]
# ### hasDamage

# %%
df["hasDamage"].unique()
#para apagar a variavel que nao tem nada de jeito
# Out:
# array([ 0., nan])

# %%
train["hasDamage"].unique()
# Out:
# array([ 0., nan])

# %%
# fazer exploração da media

# %%
train_0 = train[train["hasDamage"]== 0]
train_nan = train[~(train["hasDamage"] == 0)]

# %%
train_0["price"].median()
# Out:
# 14698.0

# %%
train_nan["price"].median()
# Out:
# 14798.0

# %%
#como nao houve diferença na media então tiramos a variavel
